# %%
import os
import numpy as np
import json

# %%
dir = '/home/bbc8731/NetMedGPT/'

param = {  
    'files': {
        'data_dir' : os.path.join(dir, 'data'),
        'model_dir': os.path.join(dir, 'model'),
    },
    'node2vec':{    
        'walk_length': 5,
        'walks_per_node' : 30, 
        'batch_size': 1024, 
        'workers': 30,
    },
    'evaluation':{
        'top_k' : np.concatenate([[5],[100]]).tolist()
    }
}

with open(os.path.join(dir, "data/parameters.json"), 'w') as file:
    json.dump(param, file)
